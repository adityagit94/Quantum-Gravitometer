# %% [markdown]
# # 01 - Run Pipeline Demo
#
# This notebook demonstrates using the package.

# %%
from pathlib import Path
from qgrav.cli import run_pipeline
report = run_pipeline(Path('../configs/example.yaml'))
report
